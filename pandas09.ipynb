# %%
import pandas as pd
import numpy as np

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(pd.Series([1,2,3,4,5]))
# Out:
# pandas.core.series.Series

# %%
data=pd.Series([1,2,3,4,5],index=["a","b","c","d","e"])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data.nme="Numbers"

# %%
data.size
# Out:
# 5

# %%
data.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
data["a"],data["c"]
# Out:
# (np.int64(1), np.int64(3))

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
data.loc["a"],data.iloc[3]
# Out:
# (np.int64(1), np.int64(4))

# %%
data.loc["a"::2],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  dtype: int64,
#  np.int64(4))

# %%
data.loc[["a","c","e"]],data.iloc[3]
# Out:
# (a    1
#  c    3
#  e    5
#  dtype: int64,
#  np.int64(4))

# %%
###DataFrames

# %%
dictionary={
    "usn":[90,68,83],
    "name":["Manasa","jayanthi","lavanya"],
    "age":[20,21,21],
    "branch":["cs","cs","AI"]
}

# %%
df=pd.DataFrame(dictionary)
df
# Out:
#    usn      name  age branch
# 0   90    Manasa   20     cs
# 1   68  jayanthi   21     cs
# 2   83   lavanya   21     AI

# %%
data=pd.read_csv(r"C:\Users\preet\Desktop\sample (1).csv")
data
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0            0    101    Ram         IT   25   50000           2  2021-01-15
# 1            1    102  Shyam         HR   30   45000           5  2019-03-10
# 2            2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3            3    104  Anita         IT   35   75000          10  2015-09-30
# 4            4    105  Kiran         HR   32   52000           7  2018-06-12
# 5            5    106   John    Finance   29   58000           3  2021-11-05
# 6            6    107  Meena         IT   41   82000          15  2010-04-18
# 7            7    108  David         HR   26   48000           2  2022-02-14
# 8            8    109   Sara    Finance   38   61000          12  2013-12-01
# 9            9    110  Arjun         IT   27   54000           4  2020-08-19
# 10          10    111   Ravi         HR   33   47000           6  2017-05-23
# ...

# %%
data.head()
# Out:
#    Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 0           0    101    Ram         IT   25   50000           2  2021-01-15
# 1           1    102  Shyam         HR   30   45000           5  2019-03-10
# 2           2    103  Geeta    Finance   28   60000           4  2020-07-22
# 3           3    104  Anita         IT   35   75000          10  2015-09-30
# 4           4    105  Kiran         HR   32   52000           7  2018-06-12
#
#         City  PerformanceScore
# 0  Bangalore               4.5
# 1     Mumbai               3.8
# 2      Delhi               4.2
# 3  Bangalore               4.9
# 4     Mumbai               4.1

# %%
data.tail()
# Out:
#     Unnamed: 0  EmpID   Name Department  Age  Salary  Experience JoiningDate  \
# 15          15    116   Neha         IT   40   88000          14  2011-10-21
# 16          16    117   Amit         HR   34   53000           8  2016-04-05
# 17          17    118  Pooja    Finance   30   57000           6  2018-12-12
# 18          18    119  Rahul         IT   28   56000           4  2020-02-28
# 19          19    120  Divya         HR   37   49500           9  2015-06-30
#
#          City  PerformanceScore
# 15  Bangalore               4.7
# 16     Mumbai               4.0
# 17      Delhi               4.1
# 18  Bangalore               3.9
# 19     Mumbai               4.3

# %%
data.describe()
# Out:
#        Unnamed: 0      EmpID        Age        Salary  Experience  \
# count    20.00000   20.00000  20.000000     20.000000   20.000000
# mean      9.50000  110.50000  32.700000  59875.000000    7.400000
# std       5.91608    5.91608   5.449288  13388.796377    4.615762
# min       0.00000  101.00000  25.000000  45000.000000    2.000000
# 25%       4.75000  105.75000  28.750000  50750.000000    4.000000
# 50%       9.50000  110.50000  31.500000  56500.000000    6.000000
# 75%      14.25000  115.25000  36.250000  61250.000000   10.250000
# max      19.00000  120.00000  45.000000  90000.000000   18.000000
#
#        PerformanceScore
# count         20.000000
# mean           4.190000
# std            0.415363
# min            3.500000
# 25%            3.900000
# 50%            4.150000
# 75%            4.425000
# max            4.900000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        20 non-null     int64
#  1   EmpID             20 non-null     int64
#  2   Name              20 non-null     object
#  3   Department        20 non-null     object
#  4   Age               20 non-null     int64
#  5   Salary            20 non-null     int64
#  6   Experience        20 non-null     int64
#  7   JoiningDate       20 non-null     object
#  8   City              20 non-null     object
#  9   PerformanceScore  20 non-null     float64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 1.7+ KB

# %%
data.shape
# Out:
# (20, 10)

# %%
data.sample()
# Out:
#     Unnamed: 0  EmpID  Name Department  Age  Salary  Experience JoiningDate  \
# 10          10    111  Ravi         HR   33   47000           6  2017-05-23
#
#       City  PerformanceScore
# 10  Mumbai               3.6

# %%
data[["Name","Department","Salary"]]
# Out:
#      Name Department  Salary
# 0     Ram         IT   50000
# 1   Shyam         HR   45000
# 2   Geeta    Finance   60000
# 3   Anita         IT   75000
# 4   Kiran         HR   52000
# 5    John    Finance   58000
# 6   Meena         IT   82000
# 7   David         HR   48000
# 8    Sara    Finance   61000
# 9   Arjun         IT   54000
# 10   Ravi         HR   47000
# 11  Priya    Finance   59000
# 12  Kunal         IT   90000
# 13  Sneha         HR   51000
# 14  Vijay    Finance   62000
# 15   Neha         IT   88000
# 16   Amit         HR   53000
# 17  Pooja    Finance   57000
# 18  Rahul         IT   56000
# 19  Divya         HR   49500

# %%
data[["Name","Department","Salary"]].head(2)
# Out:
#     Name Department  Salary
# 0    Ram         IT   50000
# 1  Shyam         HR   45000

# %%
type(data.Name)
# Out:
# pandas.core.series.Series

# %%
data=pd.read_csv(r"C:\Users\preet\Desktop\test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data[["Name","Department","Salary"]].head(3,)
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Age           1
# Department    0
# Salary        1
# dtype: int64

# %%
data.isnull()
# Out:
#    Unnamed: 0   Name    Age  Department  Salary
# 0       False  False  False       False   False
# 1       False  False  False       False   False
# 2       False  False  False       False   False
# 3       False  False   True       False   False
# 4       False  False  False       False    True
# 5       False  False  False       False   False

# %%
data.loc[:,"Name":"Department"]
# Out:
#       Name   Age Department
# 0    Alice  25.0         HR
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT
# 4      Eve  29.0         HR
# 5    Alice  25.0         HR

# %%
data.iloc[1:4,1:4]
# Out:
#       Name   Age Department
# 1      Bob  30.0         IT
# 2  Charlie  35.0    Finance
# 3    David   NaN         IT

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'N', 'A', 'D', 'S'], dtype='object')

# %%
data.rename(columns={"Name":"N","Age":"A","Department":"D","Salary":"S"},inplace=True)

# %%
data
# Out:
#    Unnamed: 0        N     A        D        S
# 0           0    Alice  25.0       HR  50000.0
# 1           1      Bob  30.0       IT  60000.0
# 2           2  Charlie  35.0  Finance  70000.0
# 3           3    David   NaN       IT  62000.0
# 4           4      Eve  29.0       HR      NaN
# 5           5    Alice  25.0       HR  50000.0

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)
data
# Out:
#          N     A        D        S
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %%
data["updated_S"]=data["S"]+5000
data
# Out:
#          N     A        D        S  updated_S
# 0    Alice  25.0       HR  50000.0    55000.0
# 1      Bob  30.0       IT  60000.0    65000.0
# 2  Charlie  35.0  Finance  70000.0    75000.0
# 3    David   NaN       IT  62000.0    67000.0
# 4      Eve  29.0       HR      NaN        NaN
# 5    Alice  25.0       HR  50000.0    55000.0

# %%
data["updated_S2"]=data["S"].map(lambda x:x+10000)

# %%
data["updated_S2"]=data["S"].map(lambda x:x+10000)

# %%
data
# Out:
#          N     A        D        S  updated_S  updated_S2  updated_S3
# 0    Alice  25.0       HR  50000.0    60000.0     60000.0     60000.0
# 1      Bob  30.0       IT  60000.0    70000.0     70000.0     70000.0
# 2  Charlie  35.0  Finance  70000.0    80000.0     80000.0     80000.0
# 3    David   NaN       IT  62000.0    72000.0     72000.0     72000.0
# 4      Eve  29.0       HR      NaN        NaN         NaN         NaN
# 5    Alice  25.0       HR  50000.0    60000.0     60000.0     60000.0

# %%
data=pd.read_csv(r"C:\Users\preet\Desktop\test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data["updated_Salary"]=data["Salary"].map(lambda x:x+10000)
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_Salary
# 0           0    Alice  25.0         HR  50000.0         60000.0
# 1           1      Bob  30.0         IT  60000.0         70000.0
# 2           2  Charlie  35.0    Finance  70000.0         80000.0
# 3           3    David   NaN         IT  62000.0         72000.0
# 4           4      Eve  29.0         HR      NaN             NaN
# 5           5    Alice  25.0         HR  50000.0         60000.0

# %%
data.dropna(inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# Name              0
# Age               0
# Department        0
# Salary            0
# updated_Salary    0
# dtype: int64

# %%
data["Age"]=data.Age.astype("int")

# %%
data[data["Age"]>25]
# Out:
#    Unnamed: 0     Name  Age Department   Salary  updated_Salary
# 1           1      Bob   30         IT  60000.0         70000.0
# 2           2  Charlie   35    Finance  70000.0         80000.0

# %%
data["Age"].mean()
# Out:
# np.float64(28.8)

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\preet\Desktop\test2.csv")
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David   NaN         IT  62000.0
# 4           4      Eve  29.0         HR      NaN
# 5           5    Alice  25.0         HR  50000.0

# %%
data["Age"]=data["Age"].fillna(value=data["Age"].mean())
data["Salary"]=data["Salary"].fillna(value=data["Salary"].mean())
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data["Department"].value_counts()
# Out:
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %%
data["Age"]=data["Age"].fillna(method="ffill")
data["Salary"]=data["Salary"].fillna(method="bfill")
data
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_24024\372067137.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Age"]=data["Age"].fillna(method="ffill")
# C:\Users\preet\AppData\Local\Temp\ipykernel_24024\372067137.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data["Salary"]=data["Salary"].fillna(method="bfill")
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
data.Age.ffill()
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary
# 0           0    Alice  25.0         HR  50000.0
# 1           1      Bob  30.0         IT  60000.0
# 2           2  Charlie  35.0    Finance  70000.0
# 3           3    David  28.8         IT  62000.0
# 4           4      Eve  29.0         HR  58400.0
# 5           5    Alice  25.0         HR  50000.0

# %%
##column wise apply()
data["updated_Salary"]=data["Salary"].apply(lambda x:x+500)

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_Salary
# 0           0    Alice  25.0         HR  50000.0         50500.0
# 1           1      Bob  30.0         IT  60000.0         60500.0
# 2           2  Charlie  35.0    Finance  70000.0         70500.0
# 3           3    David  28.8         IT  62000.0         62500.0
# 4           4      Eve  29.0         HR  58400.0         58900.0
# 5           5    Alice  25.0         HR  50000.0         50500.0

# %%
##rowwise apply

# %%
data["level"]=data.apply(lambda row: "High" if row ["Salary"]>60000 else "Low",axis = 1)

# %%
data
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_Salary level
# 0           0    Alice  25.0         HR  50000.0         50500.0   Low
# 1           1      Bob  30.0         IT  60000.0         60500.0   Low
# 2           2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3           3    David  28.8         IT  62000.0         62500.0  High
# 4           4      Eve  29.0         HR  58400.0         58900.0   Low
# 5           5    Alice  25.0         HR  50000.0         50500.0   Low

# %%
data.groupby("Department")["Salary"].mean()
# Out:
# Department
# Finance    70000.0
# HR         52800.0
# IT         61000.0
# Name: Salary, dtype: float64

# %%
 filtered = data[(data["Age"]>28)&(data["Salary"]>50000)]

# %%
filtered
# Out:
#    Unnamed: 0     Name   Age Department   Salary  updated_Salary level
# 1           1      Bob  30.0         IT  60000.0         60500.0   Low
# 2           2  Charlie  35.0    Finance  70000.0         70500.0  High
# 3           3    David  28.8         IT  62000.0         62500.0  High
# 4           4      Eve  29.0         HR  58400.0         58900.0   Low

# %%
filtered = data[(data["Age"]>28)&(data["Department"]=="IT")]

# %%
filtered
# Out:
#    Unnamed: 0   Name   Age Department   Salary  updated_Salary level
# 1           1    Bob  30.0         IT  60000.0         60500.0   Low
# 3           3  David  28.8         IT  62000.0         62500.0  High

# %%
###task 1

# %%
import pandas as pd


products = pd.Series(
    [700, 150, 300],
    index=['Laptop', 'Mouse', 'Keyboard']
)


laptop_price = products.loc['Laptop']


first_two = products.iloc[:2]

products
laptop_price
first_two
# Out:
# Laptop    700
# Mouse     150
# dtype: int64

# %%
###task 2

# %%
import pandas as pd


grades = pd.Series([85, None, 92, 45, None, 78, 55])

missing_values = grades.isnull()


filled_grades = grades.fillna(0)


filtered_scores = filled_grades[filled_grades > 60]

grades
missing_values
filled_grades
filtered_scores
# Out:
# 0    85.0
# 2    92.0
# 5    78.0
# dtype: float64

# %%
####task 3

# %%
import pandas as pd

# Create Series
usernames = pd.Series([' Alice ', 'bOB', 'Charlie_Data ', 'daisy'])

# Remove leading/trailing spaces
cleaned = usernames.str.strip()


cleaned = cleaned.str.lower()


contains_a = cleaned.str.contains('a')

usernames
cleaned
contains_a
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# dtype: bool
